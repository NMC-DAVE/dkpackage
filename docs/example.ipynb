# %% [markdown]
# # Example usage
#
# To use `dkPackage` in a project:

# %%
import dkPackage

print(dkPackage.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /media/kan-dai/workspace/workcode/temporary/package_test/dkPackage/docs/example.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bdk_ubuntu/media/kan-dai/workspace/workcode/temporary/package_test/dkPackage/docs/example.ipynb#ch0000001vscode-remote?line=0'>1</a> import dkPackage
#       <a href='vscode-notebook-cell://ssh-remote%2Bdk_ubuntu/media/kan-dai/workspace/workcode/temporary/package_test/dkPackage/docs/example.ipynb#ch0000001vscode-remote?line=2'>3</a> print(dkPackage.__version__)
#
# ModuleNotFoundError: No module named 'dkPackage'
